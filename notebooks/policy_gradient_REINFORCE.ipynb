# %% [markdown]
# # Policy Gradient - REINFORCE
#
# This code is an example using Policy Gradient Method. The code is from [this website](https://medium.com/@thechrisyoon/deriving-policy-gradients-and-implementing-reinforce-f887949bd63).
# The example uses the gym [CartPole system](https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py).
# Here we use [pyTorch](https://pytorch.org/) rather than [tensorFlow](https://www.tensorflow.org/).
# - `torch.nn` is used to inherit and use the neural network class.
# - `torch.nn.functional` is used to apply ReLU or softmax.
# - `torch.optim` is used to apply [Adam](https://machinelearningmastery.com/adam-optimization-algorithm-for-deep-learning/), a famous method for stochastic gradient descent.
# - `torch.autograd`'s `Variable` is known to be deprecated [[REF]](https://stackoverflow.com/questions/57580202/whats-the-purpose-of-torch-autograd-variable), but since the original code uses it we will leave it as it is.

# %%
import sys
import gym
import time
import numpy as np  

import torch  
import torch.nn            as nn
import torch.nn.functional as F
import torch.optim         as optim
from   torch.autograd import Variable

import matplotlib.pyplot   as plt

# %% [markdown]
# # Defining a Policy Network
#
# The policy neural network has three layers:
# - [Layer 1] Denoted as $l_1$ with $n_s$ Neurons. The input is the state of the current cart-and-pole.
# - [Layer 2] Denoted as $l_2$ with $n_{h}$ Neurons, where subscript $h$ stands for "hidden".
# - [Layer 3] Denoted as $l_3$ with $n_a$ Neurons
#
# From $l_1$ to $l_2$ and $l_2$ to $l_3$, the network uses a linear combination, i.e., using $l_1$, $l_2$ and $l_3$ as an array of values of the corresponding neurons:
# $$
# \begin{align*}
#     l_2 &= W_{12} \cdot l_1 + b_{12} \\
#     l_3 &= W_{23} \cdot l_2 + b_{23}
# \end{align*}
# $$
# where $W$ and $b$ are weight matrix and bias array, respectively.
# Note that the values are additionally fed into a nonlinear function.
# $l_2$ is fed into a ReLU (Rectified Linear Unit) function, and $l_3$ is fed into a softmax function to make it as a probability distribution function (i.e., all the values are non-negative and it sums to 1)

# %%
class PolicyNetwork( nn.Module ):
    def __init__( self, num_inputs, num_actions, hidden_size, learning_rate = 3e-4 ):
        super(PolicyNetwork, self).__init__()

        self.num_actions = num_actions
        self.linear1     = nn.Linear( num_inputs, hidden_size  )
        self.linear2     = nn.Linear( hidden_size, num_actions )
        self.optimizer   = optim.Adam( self.parameters(), lr = learning_rate )

    def forward( self, state ):
        x = F.relu( self.linear1( state ) )
        x = F.softmax( self.linear2( x ), dim = 1 )
        return x 
    
    def get_action( self, state ):
        state = torch.from_numpy( state ).float().unsqueeze( 0 )

        # Forward the neural network and return the prbability distribution function
        probs = self.forward( Variable( state ) )

        # Choosing the action based on the output policy
        highest_prob_action = np.random.choice( self.num_actions, p = np.squeeze( probs.detach( ).numpy( ) ) )

        # The log-value of the probability just for the sake of policy gradient
        log_prob            = torch.log( probs.squeeze( 0 )[ highest_prob_action ] )
        return highest_prob_action, log_prob

# %% [markdown]
# # The Goal of Policy Gradient Method!
#
# Once we parameterize the policy with a neural network $\pi_{\theta}(a|s)$, we need an objective function to conduct the gradient ascent (recall that we are optimizing rewards not costs!).
# Given a trajectory $\tau$ of Markov Decision Process with length $T$ (starts from 0, hence $T+1$ states):
# $$
#     \tau: s_0, a_0, r_1, s_1, a_1, \cdots, s_{T-1}, a_{T-1}, r_T, s_T
# $$
#
# The objective function $J(\theta)$ that we are planning to maximize is the expected value of the reward from a given trajectory:
# $$
#     J(\theta) = \mathbb{E}_{\tau \sim \pi_{\theta} }\Big[R(\tau)\Big], \;\; \text{where} \;\;     R(\tau) =\sum_{i=1}^{T}r_i
# $$
# Note that the $R(\cdot)$ function is simply the sum of all rewards of a given trajectory, and subscript $\tau \sim \pi_{\theta}$ means that the trajectory is generated following policy $\pi_{\theta}$.
# The gradient of the objective function is simply:
# $$
#     \nabla_{\theta} J(\theta) = \nabla_{\theta}\mathbb{E}_{\tau \sim \pi_{\theta} }\Big[R(\tau)\Big] = \nabla_{\theta}\mathbb{E}_{\tau \sim \pi_{\theta} }\bigg[ \sum_{i=1}^{T}r_i \bigg]
# $$
# Since it is the expectation over all possible trajectories, we use a simple trick to simplify the gradient:
# $$
#     \nabla_{\theta}\mathbb{E}_{\tau \sim \pi_{\theta} }\bigg[ R(\tau) \bigg] = \nabla_{\theta}\sum_{\tau} R(\tau) p_{\theta}(\tau) = \sum_{\tau} R(\tau) \nabla_{\theta} p_{\theta}(\tau) = \sum_{\tau} R(\tau) \frac{\nabla_{\theta} p_{\theta}(\tau)}{p_{\theta}(\tau)}p_{\theta}(\tau) = \sum_{\tau} R(\tau) p_{\theta}(\tau) \nabla_{\theta}\log{p_{\theta}(\tau)} = \mathbb{E}_{\tau \sim \pi_{\theta} }\Big[ R(\tau)\nabla_{\theta}\log{p_{\theta}(\tau)} \Big]
# $$
# Meaning, the gradient with respect to parameter $\theta$ goes into the expectation operator and we are taking the log of the probability of the trajectory.
# Our next step is to conduct a calculation of $p_{\theta}(\tau)$, $\log{p_{\theta}(\tau)}$:
# $$
# \begin{align*}
#     p_{\theta}(\tau)       & = \text{Pr}\Big[ S_0 = s_0, A_0 = a_0, \cdots, S_{T-1}=s_{T-1}, A_{T-1}=a_{T-1} \Big] \\
#                            & =  p(s_0)\cdot\pi_{\theta}(a_0|s_0)\cdot p(r_1, s_1 | a_0, s_0) \cdot \pi_{\theta}(a_1 | s_1) \cdot p(r_2, s_2 | a_1, s_1) \cdots \pi_{\theta}(a_{T-1}|s_{T-1})p(r_T, s_T | a_{T-1}, s_{T-1}) \\
#                            \\
#     \log{p_{\theta}(\tau)} & = \log{p(s_0)} + \log{\pi_{\theta}(a_0|s_0)} + \log{p(r_1, s_1 | a_0, s_0)} + \cdots + \log{\pi_{\theta}(a_{T-1}|s_{T-1})} + \log{p(r_T, s_T | a_{T-1}, s_{T-1})}  \\
#     \\
#     \nabla_{\theta}\log{p_{\theta}(\tau)} & = \nabla_{\theta} \bigg( \sum_{i=0}^{T-1} \log{\pi_{\theta}(a_i|s_i)} \bigg)
# \end{align*}
# $$
# The great point about policy gradients is the fact that only the policy terms $\pi_{\theta}(a_i|s_i)$ survive for the gradient. Summarizing,
# $$
#     \nabla_{\theta} J(\theta) = \mathbb{E}_{\tau \sim \pi_{\theta} }\Big[ R(\tau)\nabla_{\theta}\log{p_{\theta}(\tau)} \Big]
#     = \mathbb{E}_{\tau \sim \pi_{\theta} }\Bigg[ R(\tau)\nabla_{\theta} \bigg( \sum_{i=0}^{T-1} \log{\pi_{\theta}(a_i|s_i)} \bigg)  \Bigg]
#     = \mathbb{E}_{\tau \sim \pi_{\theta} }\Bigg[ \bigg( \sum_{i=1}^{T}r_i \bigg) \nabla_{\theta} \bigg( \sum_{i=0}^{T-1} \log{\pi_{\theta}(a_i|s_i)} \bigg)  \Bigg]
# $$
# And using some math tricks for the simplification [[REF]](https://danieltakeshi.github.io/2017/03/28/going-deeper-into-reinforcement-learning-fundamentals-of-policy-gradients/):
# $$
# \mathbb{E}_{\tau \sim \pi_{\theta} }\Bigg[ \bigg( \sum_{i=1}^{T}r_i \bigg) \nabla_{\theta} \bigg( \sum_{i=0}^{T-1} \log{\pi_{\theta}(a_i|s_i)} \bigg)  \Bigg] = \cdots = \mathbb{E}_{\tau \sim \pi_{\theta} }\Bigg[ \sum_{i=0}^{T-1} \nabla_{\theta} \log{\pi_{\theta}(a_i|s_i)} \bigg(\sum_{j=i+1}^{T}r_j\bigg) \Bigg]
# $$
# Note that the last term is simply the undiscounted sum of rewards, i.e., $G_t$ with $\gamma = 1$. Meaning, we can simply generalize this equation for cases with $\gamma \in [0,1)$.
#
# Summarizing, we calculate the gradient via:
# $$
#     \nabla_{\theta} J(\theta) = \mathbb{E}_{\tau \sim \pi_{\theta} }\Bigg[ \sum_{i=0}^{T-1} \nabla_{\theta} \log{\pi_{\theta}(a_i|s_i)} G_t \Bigg]
# $$

# %% [markdown]
# # REINFORCE Algorithm
# Since we introduced the theory, we show the most basic algorithm called REINFORCE, which is a Monte-Carlo variant of policy gradients. Note that Monte-Carlo methods is simply a hard way of saying "methods using random samples".
# The Monte-Carlo method is required since we cannot calculate actual "expectations" in real life $\mathbb{E}[\cdot]$. We need to somehow take samples and average it to calculate the expectations.
# The psuedo-code image is from [[REF]](http://www.cs.toronto.edu/~tingwuwang/REINFORCE.pdf).
#
# # Speeding up the python code.
# Before diving into the codes are some tips to speed-up the python code. One of the method is suppressing the usage of for-loops.
# In fact, for loops are known to be **Evil!** Please check out [this post](https://medium.com/python-pandemonium/never-write-for-loops-again-91a5a4c84baf) in case you are interested. Summarizing, it is a good exercise NOT to use for-loop, since there might be other ways that are way better and faster.
#
# We present an example that calculates the $G_t$ array from a reward trajectory. Please check below for details.

# %%
def Gt_method1( r_arr: np.ndarray, gamma: float = 1, is_print: bool = False) :
    """
        This method uses vectors for the Gt array calculation.

        Args:
            [1] r_arr: an array of rewards for each time step. 

            [2] gamma: discount ratio, valued between 0 to 1. 
                       If gamma = 1, then there is no discount applied

            [3] is_print: a boolean value which determines whether to print out the computation time or not.

        Return:
            G_t: an array of discounted (or if gamma = 1, simple sum of) rewards
    """

    start = time.time()

    N = len( r_arr )

    tmp = np.concatenate( ( np.ones( 1 ), np.cumprod( gamma * np.ones( N - 1 ) ) ) )
    Gt_arr = np.flip( np.cumsum( tmp * r_arr  ) )

    if is_print: print( "[Method 1] [Vectorization]", time.time( ) - start) 

    return Gt_arr

def Gt_method2( r_arr: np.ndarray, gamma: float = 1, is_print: bool = False ):
    """
        This method uses a brute-force for loop executation for calculating the Gt array.

        Args:
            [1] r_arr: an array of rewards for each time step. 

            [2] gamma: discount ratio, valued between 0 to 1. 
                       If gamma = 1, then there is no discount applied

            [3] is_print: a boolean value which determines whether to print out the computation time or not.

        Return:
            G_t: an array of discounted (or if gamma = 1, simple sum of) rewards
    """

    start = time.time()
    Gt_arr = []

    for t in range( len( r_arr ) ) :

        # Initialization of Gt
        Gt = 0 

        # The power for the calculation
        pw = 0
        
        for r in r_arr[ t: ] :
            Gt += gamma ** pw * r
            pw += 1

        Gt_arr.append( Gt )

    if is_print: print( "[Method 2] [For-loop] ", time.time() - start )

    return Gt_arr

# Play with this number, the effect is in fact, dramatic
N     = 1000
r_arr = np.ones( N )

# _ is just to suppress the output print of the function
Gt1 = Gt_method1( r_arr, gamma = 1, is_print = True )
Gt2 = Gt_method2( r_arr, gamma = 1, is_print = True )

# For N = 1000, method1 takes an average of 0.0001 second, while method2 take 0.17s 
# Try it yourself!
Gt_calc = Gt_method2
# Out:
# [Method 1] [Vectorization] 0.0004401206970214844
# [Method 2] [For-loop]  0.4465138912200928

# %%
def update_policy( policy_network, rewards, log_probs, is_whitening = False ):
    """
        Args:
            log_probs: list of individual tensor with pi( at | st ) value.
    """

    # This is the discount rate, it should be smaller than 1 for convergence. 
    GAMMA  = 0.9

    # Calculate the Gt_arr for the training. 
    Gt_arr = Gt_calc( rewards, GAMMA, is_print = False )
    Gt_arr = torch.tensor( Gt_arr )

    # The Gt_arr method has high variant, hence there are tricks to suppress the high variance of the approach.
    # One basic approach is 
    if is_whitening: Gt_arr = ( Gt_arr - Gt_arr.mean( ) ) / ( Gt_arr.std( ) + 1e-9 ) 

    policy_gradient = []

    for log_prob, Gt in zip( log_probs, Gt_arr ):
        policy_gradient.append( -log_prob * Gt )
        
    policy_network.optimizer.zero_grad( )
    policy_gradient = torch.stack( policy_gradient ).sum()
    policy_gradient.backward()
    policy_network.optimizer.step()

# %% [markdown]
# # Normalization of $G_t$?
# Due to practical reason, just directly using the Gt values lead to unstable + highly-variant result of the learning process.
# Thus, there are tricks that can be applied.
# The most common one is the **whitening transformation**, which is mentioned in [this post](https://medium.com/nerd-for-tech/policy-gradients-reinforce-with-baseline-6c871a3a068).
# The idea is simple: just change the $G_t$ via normalization:
#
# $$
#     \nabla_{\theta} J(\theta) = \mathbb{E}_{\tau \sim \pi_{\theta} }\Bigg[ \sum_{i=0}^{T-1} \nabla_{\theta} \log{\pi_{\theta}(a_i|s_i)} G_t \Bigg] \;\; \Longrightarrow \;\; \nabla_{\theta} J(\theta) = \mathbb{E}_{\tau \sim \pi_{\theta} }\Bigg[ \sum_{i=0}^{T-1} \nabla_{\theta} \log{\pi_{\theta}(a_i|s_i)} \frac{(G_t  - \bar{G})}{\sigma_G} \Bigg]
# $$
# where $\bar{G}$ is the mean of $T$ samples of the trajectory, and $\sigma_G$ is the standard deviation of it.
# ```
#     Gt_arr = ( Gt_arr - Gt_arr.mean( ) ) / ( Gt_arr.std() + 1e-9)  # normalize discounted rewards
# ```
# [This post](https://datascience.stackexchange.com/questions/20098/why-do-we-normalize-the-discounted-rewards-when-doing-policy-gradient-reinforcem) will be helpful.
# The bottom line is to simply stabilize the learning process by normalization, which keeps the $G_t$ value in some reasonable value range.

# %% [markdown]
# # Example - Cart-and-Pole System

# %%
# Generate the gym of Cart-and-Pole
env = gym.make( 'CartPole-v1' )

# The number of states and actions are +4 and +2
ns  = env.observation_space.shape[ 0 ]
na  = env.action_space.n

# Generate the 3-layer Policy Network.
policy_net = PolicyNetwork( ns, na, 128 ) 

# We conduct max_episode_num trails (or episodes)
max_episode_num = 2000

# For each trial, we run (e.g.,) 500 steps, i.e., T = 500 and the trajectory will be as follows:
# S0, A0, R1, S1, A1, ... S499 A499 R500, S500
# .... in case if the simulation does not reach the terminal state
max_steps       = 500

# Saving the number of steps for each trial
numsteps        = []
avg_numsteps    = []

# Saving the sum of rewards of a single trial
all_rewards     = []

# Saving the best model parameters 
best_model_val  = 0

# Whitening 
is_white = False

for episode in range( max_episode_num ):

    # gym initialization
    state     = env.reset()

    # To run gradient ascent, we need to save the array of log_probs and rewards. 
    # In detail, it is the "discounted" rewards, but the "update_policy" method executes that calculation internally. 
    log_probs = []
    rewards   = []

    # Run a single trial (i.e., a single trajectory)
    for steps in range( max_steps ):

        # env.render( )

        # Get the choice of action and the pi( a_t | s_t ) for the gradient calculation
        action, log_prob = policy_net.get_action( state )


        # The 4th argument is "info", which is some sort of additional information that we don't use for this example.
        new_state, reward, done, _ = env.step( action )

        log_probs.append( log_prob )
        rewards.append( reward )

        # If the trail encounters the terminal state
        if done: 

            numsteps.append( steps )

            # Taking the average of the number of steps for the learning process
            avg_numsteps.append( np.mean( numsteps[ -10: ] ) )

            # The rewards of the whole process. 
            sum_rewards = np.sum( rewards )
            all_rewards.append( sum_rewards )

            if best_model_val <= sum_rewards:
                best_model_val = sum_rewards 

                # If this policy has a good result, save it 
                torch.save( policy_net, '../models/PG_raw_best_model.pth') if not is_white else torch.save( policy_net, '../models/PG_white_best_model.pth')

            # Update the policy
            update_policy( policy_net, rewards, log_probs, is_whitening = is_white )

            if episode % 1 == 0:
                sys.stdout.write( "episode: {}, total reward: {}, average_reward: {}, length: {}\n".format(episode, np.round( sum_rewards, decimals = 3 ),  np.round( np.mean( all_rewards[ -10 : ] ), decimals = 3 ), steps ) )
            break

            
        state = new_state
# Out:
# episode: 0, total reward: 27.0, average_reward: 27.0, length: 26
# episode: 1, total reward: 16.0, average_reward: 21.5, length: 15
# episode: 2, total reward: 24.0, average_reward: 22.333, length: 23
# episode: 3, total reward: 16.0, average_reward: 20.75, length: 15
# episode: 4, total reward: 28.0, average_reward: 22.2, length: 27
# episode: 5, total reward: 20.0, average_reward: 21.833, length: 19
# episode: 6, total reward: 49.0, average_reward: 25.714, length: 48
# episode: 7, total reward: 40.0, average_reward: 27.5, length: 39
# episode: 8, total reward: 35.0, average_reward: 28.333, length: 34
# episode: 9, total reward: 60.0, average_reward: 31.5, length: 59
# episode: 10, total reward: 26.0, average_reward: 31.4, length: 25
# episode: 11, total reward: 19.0, average_reward: 31.7, length: 18
# episode: 12, total reward: 22.0, average_reward: 31.5, length: 21
# episode: 13, total reward: 12.0, average_reward: 31.1, length: 11
# episode: 14, total reward: 24.0, average_reward: 30.7, length: 23
# episode: 15, total reward: 49.0, average_reward: 33.6, length: 48
# episode: 16, total reward: 39.0, average_reward: 32.6, length: 38
# episode: 17, total reward: 35.0, average_reward: 32.1, length: 34
# episode: 18, total reward: 18.0, average_reward: 30.4, length: 17
# episode: 19, total reward: 28.0, average_reward: 27.2, length: 27
# episode: 20, total reward: 24.0, average_reward: 27.0, length: 23
# episode: 21, total reward: 12.0, average_reward: 26.3, length: 11
# episode: 22, total reward: 12.0, average_reward: 25.3, length: 11
# episode: 23, total reward: 94.0, average_reward: 33.5, length: 93
# episode: 24, total reward: 31.0, average_reward: 34.2, length: 30
# episode: 25, total reward: 39.0, average_reward: 33.2, length: 38
# episode: 26, total reward: 14.0, average_reward: 30.7, length: 13
# episode: 27, total reward: 63.0, average_reward: 33.5, length: 62
# episode: 28, total reward: 19.0, average_reward: 33.6, length: 18
# episode: 29, total reward: 26.0, average_reward: 33.4, length: 25
# episode: 30, total reward: 11.0, average_reward: 32.1, length: 10
# episode: 31, total reward: 13.0, average_reward: 32.2, length: 12
# episode: 32, total reward: 23.0, average_reward: 33.3, length: 22
# episode: 33, total reward: 15.0, average_reward: 25.4, length: 14
# episode: 34, total reward: 16.0, average_reward: 23.9, length: 15
# episode: 35, total reward: 31.0, average_reward: 23.1, length: 30
# episode: 36, total reward: 43.0, average_reward: 26.0, length: 42
# episode: 37, total reward: 12.0, average_reward: 20.9, length: 11
# episode: 38, total reward: 44.0, average_reward: 23.4, length: 43
# episode: 39, total reward: 34.0, average_reward: 24.2, length: 33
# episode: 40, total reward: 14.0, average_reward: 24.5, length: 13
# episode: 41, total reward: 22.0, average_reward: 25.4, length: 21
# episode: 42, total reward: 15.0, average_reward: 24.6, length: 14
# episode: 43, total reward: 26.0, average_reward: 25.7, length: 25
# episode: 44, total reward: 24.0, average_reward: 26.5, length: 23
# episode: 45, total reward: 48.0, average_reward: 28.2, length: 47
# episode: 46, total reward: 44.0, average_reward: 28.3, length: 43
# episode: 47, total reward: 28.0, average_reward: 29.9, length: 27
# episode: 48, total reward: 11.0, average_reward: 26.6, length: 10
# episode: 49, total reward: 30.0, average_reward: 26.2, length: 29
# episode: 50, total reward: 21.0, average_reward: 26.9, length: 20
# episode: 51, total reward: 27.0, average_reward: 27.4, length: 26
# episode: 52, total reward: 28.0, average_reward: 28.7, length: 27
# episode: 53, total reward: 24.0, average_reward: 28.5, length: 23
# episode: 54, total reward: 30.0, average_reward: 29.1, length: 29
# episode: 55, total reward: 30.0, average_reward: 27.3, length: 29
# episode: 56, total reward: 21.0, average_reward: 25.0, length: 20
# episode: 57, total reward: 51.0, average_reward: 27.3, length: 50
# episode: 58, total reward: 24.0, average_reward: 28.6, length: 23
# episode: 59, total reward: 21.0, average_reward: 27.7, length: 20
# episode: 60, total reward: 37.0, average_reward: 29.3, length: 36
# episode: 61, total reward: 19.0, average_reward: 28.5, length: 18
# episode: 62, total reward: 40.0, average_reward: 29.7, length: 39
# episode: 63, total reward: 20.0, average_reward: 29.3, length: 19
# episode: 64, total reward: 27.0, average_reward: 29.0, length: 26
# episode: 65, total reward: 33.0, average_reward: 29.3, length: 32
# episode: 66, total reward: 18.0, average_reward: 29.0, length: 17
# episode: 67, total reward: 37.0, average_reward: 27.6, length: 36
# episode: 68, total reward: 15.0, average_reward: 26.7, length: 14
# episode: 69, total reward: 13.0, average_reward: 25.9, length: 12
# episode: 70, total reward: 11.0, average_reward: 23.3, length: 10
# episode: 71, total reward: 21.0, average_reward: 23.5, length: 20
# episode: 72, total reward: 12.0, average_reward: 20.7, length: 11
# episode: 73, total reward: 26.0, average_reward: 21.3, length: 25
# episode: 74, total reward: 27.0, average_reward: 21.3, length: 26
# episode: 75, total reward: 20.0, average_reward: 20.0, length: 19
# episode: 76, total reward: 24.0, average_reward: 20.6, length: 23
# episode: 77, total reward: 37.0, average_reward: 20.6, length: 36
# episode: 78, total reward: 29.0, average_reward: 22.0, length: 28
# episode: 79, total reward: 15.0, average_reward: 22.2, length: 14
# episode: 80, total reward: 19.0, average_reward: 23.0, length: 18
# episode: 81, total reward: 12.0, average_reward: 22.1, length: 11
# episode: 82, total reward: 46.0, average_reward: 25.5, length: 45
# episode: 83, total reward: 25.0, average_reward: 25.4, length: 24
# episode: 84, total reward: 34.0, average_reward: 26.1, length: 33
# episode: 85, total reward: 76.0, average_reward: 31.7, length: 75
# episode: 86, total reward: 79.0, average_reward: 37.2, length: 78
# episode: 87, total reward: 26.0, average_reward: 36.1, length: 25
# episode: 88, total reward: 28.0, average_reward: 36.0, length: 27
# episode: 89, total reward: 14.0, average_reward: 35.9, length: 13
# episode: 90, total reward: 25.0, average_reward: 36.5, length: 24
# episode: 91, total reward: 21.0, average_reward: 37.4, length: 20
# episode: 92, total reward: 26.0, average_reward: 35.4, length: 25
# episode: 93, total reward: 14.0, average_reward: 34.3, length: 13
# episode: 94, total reward: 27.0, average_reward: 33.6, length: 26
# episode: 95, total reward: 37.0, average_reward: 29.7, length: 36
# episode: 96, total reward: 30.0, average_reward: 24.8, length: 29
# episode: 97, total reward: 51.0, average_reward: 27.3, length: 50
# episode: 98, total reward: 73.0, average_reward: 31.8, length: 72
# episode: 99, total reward: 46.0, average_reward: 35.0, length: 45
# episode: 100, total reward: 59.0, average_reward: 38.4, length: 58
# episode: 101, total reward: 22.0, average_reward: 38.5, length: 21
# episode: 102, total reward: 18.0, average_reward: 37.7, length: 17
# episode: 103, total reward: 23.0, average_reward: 38.6, length: 22
# episode: 104, total reward: 22.0, average_reward: 38.1, length: 21
# episode: 105, total reward: 18.0, average_reward: 36.2, length: 17
# episode: 106, total reward: 13.0, average_reward: 34.5, length: 12
# episode: 107, total reward: 8.0, average_reward: 30.2, length: 7
# episode: 108, total reward: 38.0, average_reward: 26.7, length: 37
# episode: 109, total reward: 30.0, average_reward: 25.1, length: 29
# episode: 160, total reward: 29.0, average_reward: 47.4, length: 28
# episode: 161, total reward: 20.0, average_reward: 39.6, length: 19
# episode: 162, total reward: 23.0, average_reward: 38.2, length: 22
# episode: 163, total reward: 18.0, average_reward: 34.8, length: 17
# episode: 164, total reward: 14.0, average_reward: 33.8, length: 13
# episode: 165, total reward: 29.0, average_reward: 33.9, length: 28
# episode: 166, total reward: 65.0, average_reward: 39.2, length: 64
# episode: 167, total reward: 24.0, average_reward: 33.1, length: 23
# episode: 168, total reward: 33.0, average_reward: 27.2, length: 32
# episode: 169, total reward: 56.0, average_reward: 31.1, length: 55
# episode: 170, total reward: 75.0, average_reward: 35.7, length: 74
# episode: 171, total reward: 47.0, average_reward: 38.4, length: 46
# episode: 172, total reward: 15.0, average_reward: 37.6, length: 14
# episode: 173, total reward: 45.0, average_reward: 40.3, length: 44
# episode: 174, total reward: 85.0, average_reward: 47.4, length: 84
# episode: 175, total reward: 18.0, average_reward: 46.3, length: 17
# episode: 176, total reward: 49.0, average_reward: 44.7, length: 48
# episode: 177, total reward: 17.0, average_reward: 44.0, length: 16
# episode: 178, total reward: 11.0, average_reward: 41.8, length: 10
# episode: 179, total reward: 13.0, average_reward: 37.5, length: 12
# episode: 180, total reward: 10.0, average_reward: 31.0, length: 9
# episode: 181, total reward: 22.0, average_reward: 28.5, length: 21
# episode: 182, total reward: 21.0, average_reward: 29.1, length: 20
# episode: 183, total reward: 36.0, average_reward: 28.2, length: 35
# episode: 184, total reward: 15.0, average_reward: 21.2, length: 14
# episode: 185, total reward: 15.0, average_reward: 20.9, length: 14
# episode: 186, total reward: 32.0, average_reward: 19.2, length: 31
# episode: 187, total reward: 101.0, average_reward: 27.6, length: 100
# episode: 188, total reward: 22.0, average_reward: 28.7, length: 21
# episode: 189, total reward: 24.0, average_reward: 29.8, length: 23
# episode: 190, total reward: 68.0, average_reward: 35.6, length: 67
# episode: 191, total reward: 107.0, average_reward: 44.1, length: 106
# episode: 192, total reward: 74.0, average_reward: 49.4, length: 73
# episode: 193, total reward: 21.0, average_reward: 47.9, length: 20
# episode: 194, total reward: 24.0, average_reward: 48.8, length: 23
# episode: 195, total reward: 46.0, average_reward: 51.9, length: 45
# episode: 196, total reward: 22.0, average_reward: 50.9, length: 21
# episode: 197, total reward: 109.0, average_reward: 51.7, length: 108
# episode: 198, total reward: 46.0, average_reward: 54.1, length: 45
# episode: 199, total reward: 62.0, average_reward: 57.9, length: 61
# episode: 200, total reward: 77.0, average_reward: 58.8, length: 76
# episode: 201, total reward: 19.0, average_reward: 50.0, length: 18
# episode: 202, total reward: 50.0, average_reward: 47.6, length: 49
# episode: 203, total reward: 29.0, average_reward: 48.4, length: 28
# episode: 204, total reward: 70.0, average_reward: 53.0, length: 69
# episode: 205, total reward: 44.0, average_reward: 52.8, length: 43
# episode: 206, total reward: 12.0, average_reward: 51.8, length: 11
# episode: 207, total reward: 43.0, average_reward: 45.2, length: 42
# episode: 208, total reward: 15.0, average_reward: 42.1, length: 14
# episode: 209, total reward: 24.0, average_reward: 38.3, length: 23
# episode: 1972, total reward: 239.0, average_reward: 220.5, length: 238
# episode: 1973, total reward: 176.0, average_reward: 208.6, length: 175
# episode: 1974, total reward: 235.0, average_reward: 214.9, length: 234
# episode: 1975, total reward: 229.0, average_reward: 207.0, length: 228
# episode: 1976, total reward: 326.0, average_reward: 216.3, length: 325
# episode: 1977, total reward: 233.0, average_reward: 220.5, length: 232
# episode: 1978, total reward: 180.0, average_reward: 217.6, length: 179
# episode: 1979, total reward: 284.0, average_reward: 229.4, length: 283
# episode: 1980, total reward: 210.0, average_reward: 229.4, length: 209
# episode: 1981, total reward: 170.0, average_reward: 228.2, length: 169
# episode: 1982, total reward: 221.0, average_reward: 226.4, length: 220
# episode: 1983, total reward: 406.0, average_reward: 249.4, length: 405
# episode: 1984, total reward: 177.0, average_reward: 243.6, length: 176
# episode: 1985, total reward: 306.0, average_reward: 251.3, length: 305
# episode: 1986, total reward: 301.0, average_reward: 248.8, length: 300
# episode: 1987, total reward: 274.0, average_reward: 252.9, length: 273
# episode: 1988, total reward: 161.0, average_reward: 251.0, length: 160
# episode: 1989, total reward: 128.0, average_reward: 235.4, length: 127
# episode: 1990, total reward: 196.0, average_reward: 234.0, length: 195
# episode: 1991, total reward: 355.0, average_reward: 252.5, length: 354
# episode: 1992, total reward: 334.0, average_reward: 263.8, length: 333
# episode: 1993, total reward: 232.0, average_reward: 246.4, length: 231
# episode: 1994, total reward: 330.0, average_reward: 261.7, length: 329
# episode: 1995, total reward: 188.0, average_reward: 249.9, length: 187
# episode: 1996, total reward: 122.0, average_reward: 232.0, length: 121
# episode: 1997, total reward: 500.0, average_reward: 254.6, length: 499
# episode: 1998, total reward: 178.0, average_reward: 256.3, length: 177
# episode: 1999, total reward: 155.0, average_reward: 259.0, length: 154

# %%
env.close( )
plt.plot( numsteps )
plt.plot( avg_numsteps )
plt.xlabel('Episode')
plt.show()

# %% [markdown]
# # Run the optimal policy (i.e., optimal neural network)

# %%
# Saving the path 
# model_path = "../models/PG_raw_best_model.pth"
model_path = "../models/PG_white_best_model.pth"

# Load the pyTorch Model
model = torch.load( model_path )

# Generate the gym of Cart-and-Pole
env = gym.make( 'CartPole-v1' )

# Run trial
state = env.reset()   

# The maximum trial is 500 for the cart-and-pole
for _ in range( 500 ):

    env.render( )

    # Get the choice of action and the pi( a_t | s_t ) for the gradient calculation
    action, _ = model.get_action( state )
    new_state, _, done, _ = env.step( action )

    # If the trail encounters the terminal state
    if done: 
        break
    state = new_state

# Save Video

# %% [markdown]
# # References
#
# - [1] [Great post on Github](https://github.com/dennybritz/reinforcement-learning/blob/master/PolicyGradient/README.md)
# - [2] [Policy Gradient with Stephan Curry](https://jonathan-hui.medium.com/rl-policy-gradients-explained-9b13b688b146)
# - [3] [Policy Gradient in a Nutshell](https://towardsdatascience.com/policy-gradients-in-a-nutshell-8b72f9743c5d)
# - [4] [Pong from Pixels](http://karpathy.github.io/2016/05/31/rl/)
# - [5] [Great post from Dr. Daniel Seita](https://danieltakeshi.github.io/2017/03/28/going-deeper-into-reinforcement-learning-fundamentals-of-policy-gradients/)
